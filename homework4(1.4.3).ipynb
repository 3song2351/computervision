# %% [markdown]
# ## 1.4.3 Geometric Transformations of Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# scaling

# %%
img = cv2.imread('sIMG_2164.jpg')
res = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)

# %%
cv2.imshow('image',img)
cv2.imshow('res image',res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
height, width = img.shape[:2]
res = cv2.resize(img,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)

# %% [markdown]
# ## translation

# %%
img = cv2.imread('sIMG_2164.jpg',0)
rows,cols = img.shape
M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img,M,(cols,rows))

cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Rotation

# %%
img = cv2.imread('sIMG_2164.jpg',0)
rows,cols = img.shape
cx=110
cy=0
theta=45
M = cv2.getRotationMatrix2D((cx,cy),theta,1)
dst = cv2.warpAffine(img,M,(cols,rows))
img = cv2.circle(dst,(cx,cy), 10, (0,0,255), -1)

cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Affine Transformation

# %%
img = cv2.imread('dsu4.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[235,457],[238,269],[569,231]])
pts2 = np.float32([[235,457],[235,270],[570,270]])
M = cv2.getAffineTransform(pts1,pts2)
dst = cv2.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# ## Perspective Transformation

# %%
img = cv2.imread('dsu5.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[574,338],[583,546],[761,543],[754,376]])
pts2 = np.float32([[574,338],[570,550],[770,550],[750,380]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
